# %%
# Punto de partida
precios = [8500, 32000, 15900, 7200, 54000, 12300]
impuesto = 0.19
total = 0 

for precio in precios:
    print(f"precio sin impuesto: {precio}")
    print(f"precio con impuesto: {precio*impuesto+precio}")

for valor in precios:
    total += valor

print(f"Total General: {total+total*impuesto}")




# Tu tarea: recorrer la lista, calcular el precio final de cada producto
# y acumular el total general
# Ejemplo de salida por producto: "Precio base: $8500 → Precio final: $10115.0"
# Al final: "Total general: $..."
# Out:
# precio sin impuesto: 8500
# precio con impuesto: 10115.0
# precio sin impuesto: 32000
# precio con impuesto: 38080.0
# precio sin impuesto: 15900
# precio con impuesto: 18921.0
# precio sin impuesto: 7200
# precio con impuesto: 8568.0
# precio sin impuesto: 54000
# precio con impuesto: 64260.0
# precio sin impuesto: 12300
# precio con impuesto: 14637.0
# Total General: 154581.0
