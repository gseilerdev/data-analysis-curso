# %%
# Punto de partida
monto = 45750

if monto < 1000:
    print("micro transaccion")
elif monto >= 1000 and monto <= 9999:
    print("transaccion estandar")
elif monto >= 10000 and monto <= 99999:
    print("transaccion importante")
else:
    print("transaccion de alto valor")
# Out:
# transaccion importante
