# %%
saludo = "Hola"
numero = 30
numero2 = 30
nombre_apellido = "Maria gomez"
# snake_case, no numeros adelante de la variable,
decimal = 30.5
activo = True
desconectado = False
vacio = None
nombres = ["Maria","Pablo"]
usuario = {
    "nombre":"Maria",
    "apellido":"Gomez"
}

# %%
print(saludo)
# Out:
# Hola

# %%
print(numero)
# Out:
# 30

# %%
print(nombre_apellido)
# Out:
# Maria gomez

# %%
print(decimal)
# Out:
# 30.5

# %%
print(activo)
# Out:
# True

# %%
print(desconectado)
# Out:
# False

# %%
print(vacio)
# Out:
# None

# %%
print(nombres)
# Out:
# ['Maria', 'Pablo']

# %%
print(usuario)
# Out:
# {'nombre': 'Maria', 'apellido': 'Gomez'}

# %%
print(usuario["nombre"])
# Out:
# Maria

# %%
print(type(nombres))
# Out:
# <class 'list'>

# %%
print(type(activo))
# Out:
# <class 'bool'>

# %%
print(nombres[1])
# Out:
# Pablo

# %%
# Suma
resultado = numero + int(numero2)
print (resultado)
# Out:
# 50

# %%
# Resta
resultado = numero - int(numero2)
print(resultado)
# Out:
# 10

# %%
print(saludo + " " +nombre_apellido)
# Out:
# Hola Maria gomez

# %%
print(f"{saludo} {nombre_apellido}")
# Out:
# Hola Maria gomez

# %%
print(numero == decimal)
# Out:
# False

# %%
if numero!=numero2:
    print("No tienen el mismo tipo de dato")
else:
    print("Son el mismo tipo de dato")
# Out:
# Son el mismo tipo de dato

# %%
if usuario["nombre"] == "Maria":
    print(f"Hola {usuario["nombre"]}")
elif usuario["nombre"] == "Pablo":
    print(f"Hola {usuario["nombre"]}")
else:
    print(f"Debes crearte una cuenta")
# Out:
# Hola Maria

# %%
print(numero == decimal)

# %%
for numero in range(1,6):
    print(f"Iteracion {numero}")
 #imprime: 0, 1, 2, 3,4print(1)

 iteracion 1
 interacion2
 iteracion 3
 iteracion 4
 iterecion 5

nombres = ["Maria", "Pablo", "Ada"]

for nombre in nombres:
   print(nombre)

numeros = [5,8,10,20]

for num in numeros:
   print(num*2)

frutas = ["manzana","pera","limon"]

for fruta in frutas:
   
   if fruta == "limon":
      print(f"{fruta}es")
   else:
      print(f"{fruta}s")
# Out:
# Running cells with 'Python 3.14.6' requires the ipykernel package.
#
# <a href='command:jupyter.createPythonEnvAndSelectController'>Create a Python Environment</a> with the required packages.
#
# Or install 'ipykernel' using the command: 'c:/Users/comun/.local/bin/python3.14.exe -m pip install ipykernel -U --user --force-reinstall'
