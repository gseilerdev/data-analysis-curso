# %%
def calcular_orden(precio_unitario, cantidad, descuento=0):
    subtotal = precio_unitario * cantidad
    descuento = subtotal *  (descuento / 100)
    total = subtotal - descuento

    if descuento == 0:

        return f"Subtotal: ${subtotal} | Descuento: ${descuento} | Total: ${total}"

print(calcular_orden(1200,3,0))
print(calcular_orden(8500,5,10))
print(calcular_orden(45000,2,25))


    total_final = subtotal + descuento
